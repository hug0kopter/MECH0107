# %% [markdown]
# ### Random code for neural network

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import random
from keras import layers
from keras.models import Sequential
from keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

"""
This script trains a neural network to predict the deflection (δ) of a simply supported beam under a point load 
using the beam bending equation: δ = (F * L^3) / (48 * E * I). The dataset, generated using Latin Hypercube Sampling (LHC), 
contains input features: Force (F), Length (L), Elastic Modulus (E), and Moment of Inertia (I), with δ as the output. 

The model is a feedforward neural network trained using mean squared error (MSE) loss and the Adam optimizer. 
Early stopping is used to prevent overfitting. After training, the model is evaluated on validation and test data, 
and predictions are visualized. Students are encouraged to modify key parameters (neurons, layers, activation functions, 
optimizers, etc.) to observe their impact on model performance.
"""

# ======= Uncomment for Full Reproducibility (good for debugging or model comparisons) =======
# seed = 42
# random.seed(seed)
# np.random.seed(seed)
# tf.random.set_seed(seed)
# tf.config.experimental.enable_op_determinism()  # Enable deterministic operations in TensorFlow
# tf.keras.backend.clear_session()  # Set TensorFlow backend to deterministic mode

# ======= Load Dataset =======
filename = "LectureActivity_8a_Dataset.txt"
df = pd.read_csv(filename, sep='\t')
X = df[['F (N)', 'L (m)', 'E (Pa)', 'I (m^4)']].values  # Inputs
Y = df[['δ (m)']].values  # Output

# ======= Data Preprocessing =======
# Split into training, validation, and test sets (70% train, 15% val, 15% test)
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# Standardize inputs and outputs
scaler_X = StandardScaler()
scaler_Y = StandardScaler()

X_train = scaler_X.fit_transform(X_train)
X_val = scaler_X.transform(X_val)
X_test = scaler_X.transform(X_test)

Y_train = scaler_Y.fit_transform(Y_train)
Y_val = scaler_Y.transform(Y_val)
Y_test = scaler_Y.transform(Y_test)

# ======= Build Neural Network =======
model = Sequential([
    layers.Input(shape=(X_train.shape[1],)),  # Input Layer
    layers.Dense(10, activation='relu'),  # Hidden Layer - try 'sigmoid', 'tanh', 'relu', or 'leaky_relu'
    layers.Dense(1)  # Output Layer
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.01), loss='MSE', metrics=['MAPE'])  # Try different optimisers (SGD, Adam etc.)

# ======= Train Model with Early Stopping =======
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=10,  # Stop after 10 epochs with no improvement
    restore_best_weights=True  # Restore the best weights after stopping
)

history = model.fit(
    X_train, Y_train,
    validation_data=(X_val, Y_val),
    epochs=1000,
    batch_size=32,  # Try different batch sizes (16, 32, 64, 128, etc.)
    verbose=1,
    callbacks=[early_stopping]
)

# ======= Model Evaluation =======
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Convert predictions back to original scale
def inverse_transform_and_evaluate(X, Y, scaler_Y, dataset_name):
    Y_pred = model.predict(X)
    Y_pred_original = scaler_Y.inverse_transform(Y_pred)
    Y_original = scaler_Y.inverse_transform(Y)

    # Mean Absolute Percentage Error (MAPE)
    MAPE = np.mean(np.abs((Y_original - Y_pred_original) / Y_original)) * 100
    print(f'\n MAPE_{dataset_name} (%)', MAPE)

    return Y_original, Y_pred_original, MAPE

# Evaluate on training, validation, and test sets
Y_train_original, Y_train_pred_original, MAPE_train = inverse_transform_and_evaluate(X_train, Y_train, scaler_Y, "train")
Y_val_original, Y_val_pred_original, MAPE_val = inverse_transform_and_evaluate(X_val, Y_val, scaler_Y, "val")
Y_test_original, Y_test_pred_original, MAPE_test = inverse_transform_and_evaluate(X_test, Y_test, scaler_Y, "test")

# ======= Predict a New Data Point =======
# Define a new beam scenario (custom inputs)
new_point = np.array([[250, 2.0, 30e9, 4e-3]])  # (F, L, E, I)
new_point_scaled = scaler_X.transform(new_point)
predicted_delta_scaled = model.predict(new_point_scaled)
predicted_delta = scaler_Y.inverse_transform(predicted_delta_scaled)
print(f"\nPredicted deflection (δ) for F={new_point[0,0]} N, L={new_point[0,1]} m, E={new_point[0,2]:.3e} Pa, I={new_point[0,3]:.3e} m^4, is {predicted_delta[0,0]:.3e} m")

# ======= Visualization =======
# Loss vs. Epochs
plt.figure(figsize=(8, 6))
plt.plot(train_loss, label='Training Loss', color='blue')
plt.plot(val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid()
plt.yscale('log')  # Log scale for better visualization
plt.show()

# Scatter plot of Actual vs. Predicted for Validation Set
plt.figure(figsize=(8, 6))
plt.scatter(Y_val_original, Y_val_pred_original, alpha=0.5, label='Predicted vs Actual')
plt.plot([Y_val_original.min(), Y_val_original.max()],
         [Y_val_original.min(), Y_val_original.max()],
         color='red', linestyle='--', label='Ideal Fit')  # Line of perfect predictions
plt.xlabel('Actual δ (m)')
plt.ylabel('Predicted δ (m)')
plt.legend()
plt.grid()
plt.show()
# Out:
# Epoch 1/1000
#  1/22 ━━━━━━━━━━━━━━━━━━━━ 4s 205ms/step - MAPE: 277.1819 - loss: 0.7013
# 2025-03-20 10:24:29.326879: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 2025-03-20 10:24:29.327345: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 288.2387 - loss: 0.3450 - val_MAPE: 49.0640 - val_loss: 0.0703
# Epoch 2/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 114.5234 - loss: 0.0474 - val_MAPE: 46.7641 - val_loss: 0.0479
# Epoch 3/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 75.3657 - loss: 0.0294 - val_MAPE: 44.5547 - val_loss: 0.0394
# Epoch 4/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 91.4281 - loss: 0.0214 - val_MAPE: 32.7611 - val_loss: 0.0335
# Epoch 5/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 87.3642 - loss: 0.0172 - val_MAPE: 35.2794 - val_loss: 0.0289
# Epoch 6/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 89.2319 - loss: 0.0140 - val_MAPE: 37.9270 - val_loss: 0.0246
# Epoch 7/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 87.8863 - loss: 0.0112 - val_MAPE: 37.7867 - val_loss: 0.0209
# Epoch 8/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 89.0473 - loss: 0.0091 - val_MAPE: 35.1469 - val_loss: 0.0177
# Epoch 9/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 78.6333 - loss: 0.0075 - val_MAPE: 31.0487 - val_loss: 0.0151
# Epoch 10/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 72.1191 - loss: 0.0063 - val_MAPE: 28.4787 - val_loss: 0.0133
# Epoch 11/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 61.7567 - loss: 0.0054 - val_MAPE: 27.8683 - val_loss: 0.0117
# Epoch 12/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 51.1814 - loss: 0.0047 - val_MAPE: 25.9900 - val_loss: 0.0105
# Epoch 13/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 44.2770 - loss: 0.0041 - val_MAPE: 24.3297 - val_loss: 0.0095
# Epoch 14/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 40.4594 - loss: 0.0037 - val_MAPE: 24.0284 - val_loss: 0.0087
# Epoch 15/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 35.8057 - loss: 0.0034 - val_MAPE: 23.7684 - val_loss: 0.0079
# Epoch 16/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE:
1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 33.6825 - loss: 2.5844e-04 - val_MAPE: 13.6257 - val_loss: 0.0011
# Epoch 77/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 33.9844 - loss: 2.6495e-04 - val_MAPE: 13.8019 - val_loss: 0.0012
# Epoch 78/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 32.9789 - loss: 2.8735e-04 - val_MAPE: 13.6990 - val_loss: 0.0012
# Epoch 79/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 32.1451 - loss: 3.3224e-04 - val_MAPE: 13.8530 - val_loss: 0.0013
# Epoch 80/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 32.6920 - loss: 4.0239e-04 - val_MAPE: 14.0154 - val_loss: 0.0012
# Epoch 81/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 33.0370 - loss: 4.5120e-04 - val_MAPE: 14.4249 - val_loss: 0.0013
# Epoch 82/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 35.2505 - loss: 4.6369e-04 - val_MAPE: 15.3304 - val_loss: 0.0013
# Epoch 83/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 33.3949 - loss: 3.9314e-04 - val_MAPE: 14.0318 - val_loss: 0.0014
# Epoch 84/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 24.7163 - loss: 3.5286e-04 - val_MAPE: 13.4798 - val_loss: 0.0014
# Epoch 85/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 23.5805 - loss: 3.7469e-04 - val_MAPE: 12.7001 - val_loss: 0.0014
# Epoch 86/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - MAPE: 20.1703 - loss: 3.4384e-04 - val_MAPE: 12.8894 - val_loss: 0.0015
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step
#
#  MAPE_train (%) 1.9809593171788347
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
#  MAPE_val (%) 2.781672446453925
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
#  MAPE_test (%) 2.791677270205401
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Predicted deflection (δ) for F=250.0 N, L=2.0 m, E=3.000e+10 Pa, I=4.000e-03 m^4, is 3.124e-07 m

# %% [markdown]
# ### Deterministic code for the neural network

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import random
from keras import layers
from keras.models import Sequential
from keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

"""
This script trains a neural network to predict the deflection (δ) of a simply supported beam under a point load 
using the beam bending equation: δ = (F * L^3) / (48 * E * I). The dataset, generated using Latin Hypercube Sampling (LHC), 
contains input features: Force (F), Length (L), Elastic Modulus (E), and Moment of Inertia (I), with δ as the output. 

The model is a feedforward neural network trained using mean squared error (MSE) loss and the Adam optimizer. 
Early stopping is used to prevent overfitting. After training, the model is evaluated on validation and test data, 
and predictions are visualized. Students are encouraged to modify key parameters (neurons, layers, activation functions, 
optimizers, etc.) to observe their impact on model performance.
"""

# ======= Uncomment for Full Reproducibility (good for debugging or model comparisons) =======
seed = 42
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.config.experimental.enable_op_determinism()  # Enable deterministic operations in TensorFlow
tf.keras.backend.clear_session()  # Set TensorFlow backend to deterministic mode

# ======= Load Dataset =======
filename = "LectureActivity_8a_Dataset.txt"
df = pd.read_csv(filename, sep='\t')
X = df[['F (N)', 'L (m)', 'E (Pa)', 'I (m^4)']].values  # Inputs
Y = df[['δ (m)']].values  # Output

# ======= Data Preprocessing =======
# Split into training, validation, and test sets (70% train, 15% val, 15% test)
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# Standardize inputs and outputs
scaler_X = StandardScaler()
scaler_Y = StandardScaler()

X_train = scaler_X.fit_transform(X_train)
X_val = scaler_X.transform(X_val)
X_test = scaler_X.transform(X_test)

Y_train = scaler_Y.fit_transform(Y_train)
Y_val = scaler_Y.transform(Y_val)
Y_test = scaler_Y.transform(Y_test)

# ======= Build Neural Network =======
model = Sequential([
    layers.Input(shape=(X_train.shape[1],)),  # Input Layer
    layers.Dense(10, activation='relu'),  # Hidden Layer - try 'sigmoid', 'tanh', 'relu', or 'leaky_relu'
    layers.Dense(10, activation='relu'),  # Hidden Layer - try 'sigmoid', 'tanh', 'relu', or 'leaky_relu'
    layers.Dense(1)  # Output Layer
])

# Compile the model
model.compile(optimizer=SGD(learning_rate=0.01), loss='MSE', metrics=['MAPE'])  # Try different optimisers (SGD, Adam etc.)

# ======= Train Model with Early Stopping =======
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=10,  # Stop after 10 epochs with no improvement
    restore_best_weights=True  # Restore the best weights after stopping
)

history = model.fit(
    X_train, Y_train,
    validation_data=(X_val, Y_val),
    epochs=1000,
    batch_size=32,  # Try different batch sizes (16, 32, 64, 128, etc.)
    verbose=1,
    callbacks=[early_stopping]
)

# ======= Model Evaluation =======
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Convert predictions back to original scale
def inverse_transform_and_evaluate(X, Y, scaler_Y, dataset_name):
    Y_pred = model.predict(X)
    Y_pred_original = scaler_Y.inverse_transform(Y_pred)
    Y_original = scaler_Y.inverse_transform(Y)

    # Mean Absolute Percentage Error (MAPE)
    MAPE = np.mean(np.abs((Y_original - Y_pred_original) / Y_original)) * 100
    print(f'\n MAPE_{dataset_name} (%)', MAPE)

    return Y_original, Y_pred_original, MAPE

# Evaluate on training, validation, and test sets
Y_train_original, Y_train_pred_original, MAPE_train = inverse_transform_and_evaluate(X_train, Y_train, scaler_Y, "train")
Y_val_original, Y_val_pred_original, MAPE_val = inverse_transform_and_evaluate(X_val, Y_val, scaler_Y, "val")
Y_test_original, Y_test_pred_original, MAPE_test = inverse_transform_and_evaluate(X_test, Y_test, scaler_Y, "test")

# ======= Predict a New Data Point =======
# Define a new beam scenario (custom inputs)
new_point = np.array([[250, 2.0, 30e9, 4e-3]])  # (F, L, E, I)
new_point_scaled = scaler_X.transform(new_point)
predicted_delta_scaled = model.predict(new_point_scaled)
predicted_delta = scaler_Y.inverse_transform(predicted_delta_scaled)
print(f"\nPredicted deflection (δ) for F={new_point[0,0]} N, L={new_point[0,1]} m, E={new_point[0,2]:.3e} Pa, I={new_point[0,3]:.3e} m^4, is {predicted_delta[0,0]:.3e} m")

# ======= Visualization =======
# Loss vs. Epochs
plt.figure(figsize=(8, 6))
plt.plot(train_loss, label='Training Loss', color='blue')
plt.plot(val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid()
plt.yscale('log')  # Log scale for better visualization
plt.show()

# Scatter plot of Actual vs. Predicted for Validation Set
plt.figure(figsize=(8, 6))
plt.scatter(Y_val_original, Y_val_pred_original, alpha=0.5, label='Predicted vs Actual')
plt.plot([Y_val_original.min(), Y_val_original.max()],
         [Y_val_original.min(), Y_val_original.max()],
         color='red', linestyle='--', label='Ideal Fit')  # Line of perfect predictions
plt.xlabel('Actual δ (m)')
plt.ylabel('Predicted δ (m)')
plt.legend()
plt.grid()
plt.show()
# Out:
# Epoch 1/1000
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 331.6245 - loss: 0.9237 - val_MAPE: 187.6674 - val_loss: 0.7317
# Epoch 2/1000
#  1/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step